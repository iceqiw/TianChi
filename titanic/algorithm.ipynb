# %% [markdown]
# # Sigmoid

# %% [markdown]
# ![image.png](attachment:8ff58650-8ae3-4345-88f0-27f67e139fde.png)

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import math 
  
x = np.linspace(-10, 10, 100) 
z = 1/(1 + np.exp(-x)) -0.5
  
plt.plot(x, z) 
plt.xlabel("x") 
plt.ylabel("Sigmoid(X)") 
  
plt.show()

# %% [markdown]
# https://www.cnblogs.com/wj-1314/p/10181876.html
